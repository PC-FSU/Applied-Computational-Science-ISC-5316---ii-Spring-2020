# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
#ax = plt.axes(projection='3d')
from scipy.interpolate import griddata

# %%
file_1000 = np.loadtxt('Coords_1000');
file_5000 = np.loadtxt('Coords_5000');
file_7500 = np.loadtxt('Coords_7500');
file_10000 = np.loadtxt('Coords_10000');

# %%
def PLOT(file):
    x = file[:,0]
    y = file[:,1]
    z = file[:,2]
    plt.figure(figsize=(10,10))
    print("Gloabla MiN = ",np.min(z))
    plt.scatter(x,y,color = 'k')
    xlin = np.linspace(-20,20,20)
    ylin = np.linspace(-20,20,20)
    X, Y = np.meshgrid(xlin, ylin)
    Z = 1 + np.power(np.sin(X),2) + np.power(np.sin(Y),2) - 0.1 * np.exp(-X**2 - Y**2)
    plt.contour(X,Y,Z)

# %%
PLOT(file_1000)
# Out:
# Gloabla MiN =  0.963828

# %%
PLOT(file_5000)
# Out:
# Gloabla MiN =  0.90087

# %%
PLOT(file_7500)
# Out:
# Gloabla MiN =  0.900038

# %%
PLOT(file_10000)
# Out:
# Gloabla MiN =  0.900002
